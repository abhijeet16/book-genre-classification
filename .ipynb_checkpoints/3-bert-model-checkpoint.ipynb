# %% [markdown]
# # Libraries

# %%
# Libraries
import numpy as np
import pandas as pd

import torch

from transformers import RobertaConfig
import tensorflow_hub as hub
import tensorflow_text

# %%
# Uncomment the below code for necessary downloads
#
#!pip install tensorflow_text

# %% [markdown]
# # Check for GPU

# %%
if torch.cuda.is_available():  
    device = torch.device("cuda")
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# No GPU available, using the CPU instead.

# %% [markdown]
# # Import data

# %%
# Import data
data = pd.read_csv("data/preprocess_data.csv")
data
# Out:
#                                                   title    genre  \
# 0                                     Drowned Wednesday  fantasy
# 1                                         The Lost Hero  fantasy
# 2                             The Eyes of the Overworld  fantasy
# 3                                       Magic's Promise  fantasy
# 4                                        Taran Wanderer  fantasy
# ...                                                 ...      ...
# 3097                                        Wintersmith  fantasy
# 3098  Fantastic Beasts and Where to Find Them: The O...  fantasy
# 3099                                            Hounded  fantasy
# 3100                                         Red Rising  fantasy
# 3101                                           Radiance  fantasy
#
#                                                 summary  word_count
# 0     drown wednesday first truste among morrow day ...         803
# 1     book open jason awaken school unabl rememb any...         563
# 2     cugel easili persuad merchant fianosth attempt...         334
# 3     book open herald mage vanyel return countri va...         776
# 4     taran gurgi return caer dallben follow event t...        1190
# ...                                                 ...         ...
# 3097  tiffani ach traine witch work serious scari mi...         132
# 3098  rowl screenwrit debut captur excit hardcov edi...         117
# 3099  atticus sullivan last druid life peac arizona ...         144
# 3100  live dream child born free say like land fathe...         244
# 3101  princ valu brishen khaskem princ live content ...         195
#
# [3102 rows x 4 columns]

# %% [markdown]
# # BERT Model

# %%
num_labels = data.genre.nunique()

# Initializing a RoBERTa configuration
configuration = RobertaConfig()
configuration.num_labels = num_labels

# %%
sentences = data['summary']

# %%
# bert preprocessorhttps://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3
preprocessor = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")

# bert encoder: https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-512_A-8/2
encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-512_A-8/2",trainable=True)
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.

# %%
# preprocessing dataset adding cls sep etc 
inputs = preprocessor(sentences)

# feeding it to model for vectorization
outputs = encoder(inputs)

# %%
# Check the shape of sequence outputs
outputs['sequence_output'].shape
# Out:
# TensorShape([3102, 128, 512])

# %%
# Create data frame for bert features
bert = pd.DataFrame()

# %%
for i in range(0, len(outputs['sequence_output'])):
  so = outputs['sequence_output'][i].numpy().sum(axis=0)
  bert = bert.append(pd.Series(so),ignore_index=True)
    
print('values added in dataframe')
# Out:
# C:\Users\anand\AppData\Local\Temp/ipykernel_7124/3814023560.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bert = bert.append(pd.Series(so),ignore_index=True)
# C:\Users\anand\AppData\Local\Temp/ipykernel_7124/3814023560.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bert = bert.append(pd.Series(so),ignore_index=True)
# values added in dataframe

# %%
bert
# Out:
#             0          1          2          3          4          5    \
# 0     34.064705  22.735920 -76.582848 -54.817326 -36.221695   3.004882
# 1     44.634422  53.019367 -75.831757  -3.843476 -38.149925 -10.051599
# 2     23.813639  61.292953 -48.090878 -26.896975 -70.302803  26.154720
# 3     34.096478  70.980110 -72.184326 -49.600845 -36.909424  -5.688858
# 4     29.388363  61.366852 -70.836609 -66.867935 -20.526585   5.349851
# ...         ...        ...        ...        ...        ...        ...
# 3097  12.125149  64.377953 -48.617119  -8.084726 -30.780540   4.701486
# 3098  30.124966  34.602913 -47.694775 -30.060091 -50.993698  30.277813
# 3099  29.080410  48.350159 -92.401459 -37.765911 -52.237633  24.671877
# 3100  27.993219  46.849545 -52.659748 -13.563160 -48.469765  22.498436
# 3101  11.501946  39.462524 -25.756334 -26.065933 -28.610842  11.391742
#
#             6          7          8          9    ...        502        503  \
# 0     32.512608 -11.660388 -22.189047 -14.774579  ... -58.249287 -40.098869
# 1     43.763599  -7.165840 -38.409206 -16.900696  ... -70.121567 -14.141790
# 2     37.612103 -13.753791  -5.820881 -10.963672  ... -76.458641 -24.738899
# 3     13.047146  15.227018 -31.379810 -45.028973  ... -67.968811 -30.079834
# 4     11.215246  -4.479660 -36.570850  -9.955334  ... -91.066353 -39.021122
# ...         ...        ...        ...        ...  ...        ...        ...
# 3097  30.305477 -26.343121 -69.043503  13.660601  ... -92.400650 -24.641556
# 3098  57.927208  24.578543 -16.731558 -23.782059  ... -61.238155 -41.059681
# 3099  30.593655  23.596363 -30.915812 -17.476912  ... -85.544731 -19.823086
# 3100  46.433445  26.110325 -25.438171 -29.787111  ... -85.879852 -25.784689
# 3101  23.981989  -3.021160 -40.220089 -23.111284  ... -87.594398 -23.454586
#
#             504        505        506        507        508         509  \
# 0    -51.064007  43.838612  40.184414  46.617764  57.307362   79.453125
# 1    -73.912643  53.756992  12.076204  27.182837  36.107281  136.759613
# 2    -95.690552  51.725262  13.726544  29.130074  36.723839   34.560719
# 3    -63.493378  41.449932 -11.426052  54.869556  42.769337   90.878685
# 4    -81.629021  37.976974  -0.961639  76.855942  49.196911   42.216511
# ...         ...        ...        ...        ...        ...         ...
# 3097 -66.916298  35.537956  -6.504138  21.731955  49.664429   81.811951
# 3098 -49.547863  46.638039  18.759777  -3.994585  43.995285   56.942993
# 3099 -63.061943  58.735950 -36.939617  39.063965  22.339619   45.772694
# 3100 -47.455830  54.880508   8.015970  41.336716  12.458059  102.638893
# 3101 -50.275131  26.139008 -33.775517  42.353653  50.109287   84.652588
#
#             510        511
# 0     67.457970  60.330944
# 1     56.508595  43.257900
# 2     21.573721  71.547203
# 3     68.338593  47.883766
# 4     67.465775  77.140923
# ...         ...        ...
# 3097  51.950375  38.102707
# 3098   1.023269  25.830317
# 3099  31.699293  40.172459
# 3100  21.027193  46.415066
# 3101  30.823772  46.225555
#
# [3102 rows x 512 columns]

# %% [markdown]
# # Export Bert Features

# %%
bert.to_csv( "data/bertFeatures.csv", index=False, encoding='utf-8-sig')
