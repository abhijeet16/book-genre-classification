# %%
import numpy as np
import pandas as pd

import re
import string

from IPython.display import clear_output

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

clear_output()

# %%
data = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#    index                      title    genre  \
# 0      0          Drowned Wednesday  fantasy
# 1      1              The Lost Hero  fantasy
# 2      2  The Eyes of the Overworld  fantasy
# 3      3            Magic's Promise  fantasy
# 4      4             Taran Wanderer  fantasy
#
#                                              summary
# 0   Drowned Wednesday is the first Trustee among ...
# 1   As the book opens, Jason awakens on a school ...
# 2   Cugel is easily persuaded by the merchant Fia...
# 3   The book opens with Herald-Mage Vanyel return...
# 4   Taran and Gurgi have returned to Caer Dallben...

# %%
data.genre.value_counts()
# Out:
# thriller      1023
# fantasy        876
# science        647
# history        600
# horror         600
# crime          500
# romance        111
# psychology     100
# sports         100
# travel         100
# Name: genre, dtype: int64

# %%
data = data.drop(['index'], axis=1)

# %%
data.isnull().sum()
# Out:
# title      0
# genre      0
# summary    0
# dtype: int64

# %%
data.nunique()
# Out:
# title      4296
# genre        10
# summary    4542
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
#cleaning unecessary text from the string 
def data_clean(text):
    
    # Convert to lowerCase
    text = text.lower() 
    
    # removing punctuation
    text = re.sub('[%s]' % re.escape(string.punctuation), ' ',text) 
    
    # Remove stopwords
    text_tokens = word_tokenize(text)
    tw = [word for word in text_tokens if not word in stopwords.words('english')]
    text = (" ").join(tw)
    
    split_text = text.split(' ')
    
    # Remove words with length<=3
    output = [x for x in split_text if len(x) > 3]
    text = (" ").join(output)
    
    text = re.sub(r"\s+[a-zA-Z]\s+", ' ', text) #removing single character 
    text = re.sub('<.*?>+',' ',text) #removing HTML Tags
    text = re.sub('\n', ' ',text) #removal of new line characters
    text = re.sub(r'\s+', ' ',text) #removal of multiple spaces
    
    return text

# %%
data['summary'] = data['summary'].apply(data_clean)
data['title'] = data['title'].apply(data_clean)

# %%
data
# Out:
#                           title    genre  \
# 0             drowned wednesday  fantasy
# 1                     lost hero  fantasy
# 2                eyes overworld  fantasy
# 3                 magic promise  fantasy
# 4                taran wanderer  fantasy
# ...                         ...      ...
# 4652                    hounded  fantasy
# 4653  charlie chocolate factory  fantasy
# 4654                     rising  fantasy
# 4655                  frostbite  fantasy
# 4656                   radiance  fantasy
#
#                                                 summary
# 0     drowned wednesday first trustee among morrow d...
# 1     book opens jason awakens school unable remembe...
# 2     cugel easily persuaded merchant fianosther att...
# 3     book opens herald mage vanyel returning countr...
# 4     taran gurgi returned caer dallben following ev...
# ...                                                 ...
# 4652  atticus sullivan last druids lives peacefully ...
# 4653  charlie bucket wonderful adventure begins find...
# 4654  live dream children born free says like land f...
# 4655  rose loves dimitri dimitri might love tasha ma...
# 4656  prince value brishen khaskem prince lived cont...
#
# [4657 rows x 3 columns]

# %% [markdown]
# # Preprocessing

# %%
def data_preprocess(text):
    
    # Tokenization
    tokens = word_tokenize(text)
    
    # Lemmetization
    tokens = [WordNetLemmatizer().lemmatize(word) for word in tokens]
    
    # Stemming
    tokens = [SnowballStemmer(language = 'english').stem(word) for word in tokens]
    
    return " ".join(tokens)

# %%
data['summary'] = data['summary'].apply(data_preprocess)
data['title'] = data['title'].apply(data_preprocess)
data
# Out:
#                       title    genre  \
# 0           drown wednesday  fantasy
# 1                 lost hero  fantasy
# 2             eye overworld  fantasy
# 3              magic promis  fantasy
# 4              taran wander  fantasy
# ...                     ...      ...
# 4652                  hound  fantasy
# 4653  charli chocol factori  fantasy
# 4654                   rise  fantasy
# 4655               frostbit  fantasy
# 4656                radianc  fantasy
#
#                                                 summary
# 0     drown wednesday first truste among morrow day ...
# 1     book open jason awaken school unabl rememb any...
# 2     cugel easili persuad merchant fianosth attempt...
# 3     book open herald mage vanyel return countri va...
# 4     taran gurgi return caer dallben follow event t...
# ...                                                 ...
# 4652  atticus sullivan last druid life peac arizona ...
# 4653  charli bucket wonder adventur begin find willi...
# 4654  live dream child born free say like land fathe...
# 4655  rose love dimitri dimitri might love tasha mas...
# 4656  princ valu brishen khaskem princ live content ...
#
# [4657 rows x 3 columns]

# %% [markdown]
# ## BERT

# %%
import torch

# %%
if torch.cuda.is_available():  
    device = torch.device("cuda")
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# No GPU available, using the CPU instead.

# %%
from transformers import RobertaConfig

# Initializing a RoBERTa configuration
configuration = RobertaConfig()

configuration.num_labels = num_labels

# %%
# !pip install tensorflow_text
# Out:
# Collecting tensorflow_text
#   Downloading tensorflow_text-2.10.0-cp39-cp39-win_amd64.whl (5.0 MB)
#      ---------------------------------------- 5.0/5.0 MB 3.5 MB/s eta 0:00:00
# Collecting tensorflow<2.11,>=2.10.0
#   Downloading tensorflow-2.10.1-cp39-cp39-win_amd64.whl (455.9 MB)
#      -------------------------------------- 455.9/455.9 MB 2.1 MB/s eta 0:00:00
# Collecting tensorflow-hub>=0.8.0
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
#      -------------------------------------- 108.8/108.8 KB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.1.2)
# Collecting tensorboard<2.11,>=2.10
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      ---------------------------------------- 5.9/5.9 MB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.14.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (3.6.0)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp39-cp39-win_amd64.whl (895 kB)
#      ------------------------------------- 895.9/895.9 KB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.6.3)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: setuptools in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (58.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (0.25.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.0.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (14.0.1)
# Requirement already satisfied: packaging in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (21.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.16.0)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      -------------------------------------- 438.7/438.7 KB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (4.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (3.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (2.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.22.3)
# Collecting keras<2.11,>=2.10.0
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.44.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.11,>=2.10.0->tensorflow_text) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (2.1.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (3.3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (2.6.6)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from packaging->tensorflow<2.11,>=2.10.0->tensorflow_text) (2.4.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (4.11.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (2.0.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (3.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\anand\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (3.2.0)
# Installing collected packages: keras, tensorflow-estimator, protobuf, gast, tensorflow-hub, tensorboard, tensorflow, tensorflow_text
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.1
#     Uninstalling protobuf-3.20.1:
#       Successfully uninstalled protobuf-3.20.1
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.0
#     Uninstalling tensorflow-2.8.0:
#       Successfully uninstalled tensorflow-2.8.0
# Successfully installed gast-0.4.0 keras-2.10.0 protobuf-3.19.6 tensorboard-2.10.1 tensorflow-2.10.1 tensorflow-estimator-2.10.0 tensorflow-hub-0.12.0 tensorflow_text-2.10.0
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\anand\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# libraries
import tensorflow_hub as hub
import tensorflow_text
import numpy as np
import pandas as pd

# %%
sentences=data['summary']

# %%
# bert preprocessorhttps://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3
preprocessor = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
# bert encoder https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-512_A-8/2
# encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-24_H-1024_A-16/4",trainable=True)
encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-512_A-8/2",trainable=True)
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.

# %%
# preprocessing dataset adding cls sep etc 
inputs = preprocessor(sentences)
# feeding it to model for vectorization
outputs = encoder(inputs)

# %%
outputs['sequence_output'].shape
# Out:
# TensorShape([4657, 128, 512])

# %%
# defining dataframe!!!
temp=pd.DataFrame()

# %%
for i in range(0,len(outputs['sequence_output'])):
  b=outputs['sequence_output'][i].numpy().sum(axis=0)
  temp=temp.append(pd.Series(b),ignore_index=True)
print('values added in dataframe')
# Out:
# C:\Users\anand\AppData\Local\Temp/ipykernel_9256/2331112745.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp=temp.append(pd.Series(b),ignore_index=True)
# C:\Users\anand\AppData\Local\Temp/ipykernel_9256/2331112745.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp=temp.append(pd.Series(b),ignore_index=True)
# values added in dataframe

# %%
temp.to_csv( "bertFeatures.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# # Import Bert features

# %%
bert_features = pd.read_csv("bertFeatures.csv")

# %%
bert_features
# Out:
#               0          1          2          3          4          5  \
# 0     34.064705  22.735920 -76.582850 -54.817326 -36.221695   3.004882
# 1     43.899307  50.765804 -78.818410  -4.097647 -40.782326  -9.905100
# 2     24.891432  60.095640 -52.281883 -26.142065 -70.368670  24.526697
# 3     34.096478  70.980110 -72.184326 -49.600845 -36.909424  -5.688858
# 4     29.388363  61.366850 -70.836610 -66.867935 -20.526585   5.349851
# ...         ...        ...        ...        ...        ...        ...
# 4652  29.080410  48.350160 -92.401460 -37.765910 -52.237633  24.671877
# 4653  19.129667  37.764442 -41.877934  30.918592 -55.779533  -7.655437
# 4654  27.993220  46.849545 -52.659748 -13.563160 -48.469765  22.498436
# 4655   1.865901  18.807083 -28.955233 -30.521412 -21.315687 -13.949568
# 4656  11.501946  39.462524 -25.756334 -26.065933 -28.610842  11.391742
#
#               6          7          8          9  ...        502        503  \
# 0     32.512608 -11.660388 -22.189047 -14.774579  ... -58.249287 -40.098870
# 1     44.566395  -6.893873 -37.779880 -19.604008  ... -68.393990 -12.560373
# 2     36.205227 -14.707609  -4.904492 -12.611858  ... -74.690920 -21.309294
# 3     13.047146  15.227018 -31.379810 -45.028973  ... -67.968810 -30.079834
# 4     11.215246  -4.479660 -36.570850  -9.955334  ... -91.066350 -39.021122
# ...         ...        ...        ...        ...  ...        ...        ...
# 4652  30.593655  23.596363 -30.915812 -17.476912  ... -85.544730 -19.823086
# 4653  24.861279   3.303953 -93.898900  25.722233  ... -73.550820 -40.980957
# 4654  46.433445  26.110325 -25.438171 -29.787111  ... -85.879850 -25.784689
# 4655  25.535060   3.473431 -40.239048 -18.172094  ... -78.159840 -12.696408
# 4656  23.981989  -3.021160 -40.220090 -23.111284  ... -87.594400 -23.454586
#
#             504        505        506        507        508         509  \
# 0    -51.064007  43.838610  40.184414  46.617764  57.307360   79.453125
# 1    -69.058846  53.500942   9.692698  25.433218  40.799380  131.952440
# 2    -92.245476  50.616234  12.086532  27.438631  38.936546   30.548628
# 3    -63.493378  41.449932 -11.426052  54.869556  42.769337   90.878685
# 4    -81.629020  37.976974  -0.961639  76.855940  49.196910   42.216510
# ...         ...        ...        ...        ...        ...         ...
# 4652 -63.061943  58.735950 -36.939617  39.063965  22.339619   45.772694
# 4653 -51.615788  38.190166  32.322105  23.301435  37.389750  101.013750
# 4654 -47.455830  54.880510   8.015970  41.336716  12.458059  102.638890
# 4655 -51.373646  56.125122  -2.669002  43.187996  48.552357  145.647660
# 4656 -50.275130  26.139008 -33.775517  42.353653  50.109287   84.652590
#
#             510        511
# 0     67.457970  60.330944
# 1     55.487823  44.115578
# 2     21.183413  70.788670
# 3     68.338590  47.883766
# 4     67.465775  77.140920
# ...         ...        ...
# 4652  31.699293  40.172460
# 4653  67.409850   9.669949
# 4654  21.027193  46.415066
# 4655  39.892544  22.021894
# 4656  30.823772  46.225555
#
# [4657 rows x 512 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# random forest model
X=bert_features
y=data['genre']
# # defining classifier
clf=RandomForestClassifier()
# # 10 fold cross validation
scores = cross_val_score(clf, X, y, cv=10)

# %%
import numpy as np
print('random forest results ->', np.mean(scores))
# Out:
# random forest results -> 0.5031164336148415

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
clf = RandomForestClassifier()
clf.fit(X_train, y_train)

from sklearn.metrics import accuracy_score

res=clf.predict(X_test)
accuracy_score(y_test, res)
# Out:
# 0.5092989985693849

# %%
## SVC
from sklearn import svm

clf=svm.SVC()
# 10 fold cross validation
SVCscores = cross_val_score(clf, X, y, cv=10)

# %%
print('svc results-->', np.mean(SVCscores))
# Out:
# svc results--> 0.5750473025981817
